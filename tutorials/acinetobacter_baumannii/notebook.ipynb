# %%
# %%bash
# curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba
# ./bin/micromamba create -y -p ./amrfinder -c conda-forge -c bioconda ncbi-amrfinderplus

# %%
# !uv pip install ppanggolin
